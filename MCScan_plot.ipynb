# %% [markdown]
# <a href="https://colab.research.google.com/github/hlepushe/comparative-genetics_HW/blob/main/MCScan_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q condacolab

# %%
import condacolab

# %%
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:12
# 🔁 Restarting kernel...

# %%
# !conda --version
# Out:
# conda 23.11.0

# %%
# !conda install jcvi -c conda-forge -c bioconda
# Out:
# Channels:
#  - conda-forge
#  - bioconda
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - jcvi
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _r-mutex-1.0.1             |      anacondar_1           3 KB  conda-forge
#     alsa-lib-1.2.12            |       h4ab18f5_0         543 KB  conda-forge
#     argcomplete-3.5.1          |     pyhd8ed1ab_0          40 KB  conda-forge
#     argh-0.31.3                |     pyhd8ed1ab_0          44 KB  conda-forge
#     atk-1.0-2.38.0             |       hd4edc92_1         539 KB  conda-forge
# ...

# %%
# !conda install bioconda::last
# Out:
# Channels:
#  - conda-forge
#  - bioconda
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# # All requested packages already installed.

# %%
# !python -m jcvi.compara.catalog ortholog chr4_ref chr4_samp --no_strip_names
# Out:
# [11/12/24 14:29:09] DEBUG    lastdb chr4_samp chr4_samp.cds                             ]8;id=252978;file:///usr/local/lib/python3.10/site-packages/jcvi/apps/base.py\base.py]8;;\:]8;id=268237;file:///usr/local/lib/python3.10/site-packages/jcvi/apps/base.py#1191\1191]8;;\
# [11/12/24 14:29:12] DEBUG    lastal -u 0 -i3G -f BlastTab -P 2 chr4_samp chr4_ref.cds   ]8;id=914942;file:///usr/local/lib/python3.10/site-packages/jcvi/apps/base.py\base.py]8;;\:]8;id=32669;file:///usr/local/lib/python3.10/site-packages/jcvi/apps/base.py#1191\1191]8;;\
#                              >./chr4_ref.chr4_samp.last
# [11/12/24 14:29:48] DEBUG    Assuming --qbed=chr4_ref.bed --sbed=chr4_samp.bed        ]8;id=544773;file:///usr/local/lib/python3.10/site-packages/jcvi/compara/synteny.py\synteny.py]8;;\:]8;id=99901;file:///usr/local/lib/python3.10/site-packages/jcvi/compara/synteny.py#390\390]8;;\
# ...
